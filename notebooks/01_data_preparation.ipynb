# %%
import pandas as pd
import pandas_datareader.data as web
import datetime as dt
import os

# %%
os.makedirs("../data/raw", exist_ok=True)



start = dt.datetime(1990, 1, 1)
end = dt.datetime.today()

print("Downloading Brent oil price from FRED...")
oil = web.DataReader("DCOILBRENTEU", "fred", start, end)
oil.rename(columns={"DCOILBRENTEU": "oil_price"}, inplace=True)

oil.to_csv("../data/raw/oil_price_fred.csv")
print("Saved: data/raw/oil_price_fred.csv")


print("Downloading CPI (inflation) from FRED...")
cpi = web.DataReader("CPIAUCSL", "fred", start, end)
cpi.rename(columns={"CPIAUCSL": "cpi"}, inplace=True)

cpi.to_csv("../data/raw/cpi_fred.csv")
print("Saved: data/raw/cpi_fred.csv")


print("Loading household consumption from World Bank CSV...")
cons = pd.read_csv("../data/raw/consumption_worldbank.csv")

cons = cons[cons["Country Code"] == "DEU"]

year_cols = [col for col in cons.columns if col.isdigit()]
cons = cons[year_cols].T
cons.columns = ["consumption"]

cons.index = pd.to_datetime(cons.index)
cons = cons.asfreq("A")

cons.to_csv("../data/raw/consumption_worldbank_clean.csv")
print("Saved: data/raw/consumption_worldbank_clean.csv")

print("Loading GDP from World Bank CSV...")
gdp = pd.read_csv(
    "../data/raw/gdp_worldbank.csv",
    skiprows=4,        # World Bank metadata rows
)


gdp = gdp[gdp["Country Code"] == "DEU"]
year_cols = [col for col in gdp.columns if col.isdigit()]
gdp = gdp[year_cols].T
gdp.columns = ["gdp"]

gdp.index = pd.to_datetime(gdp.index)
gdp = gdp.asfreq("A")

gdp.to_csv("../data/raw/gdp_worldbank_clean.csv")
print("Saved: data/raw/gdp_worldbank_clean.csv")

print("\nAll datasets downloaded and saved successfully!")
# Out:
# Downloading Brent oil price from FRED...
# Saved: data/raw/oil_price_fred.csv
# Downloading CPI (inflation) from FRED...
# Saved: data/raw/cpi_fred.csv
# Loading household consumption from World Bank CSV...
# Saved: data/raw/consumption_worldbank_clean.csv
# Loading GDP from World Bank CSV...
# Saved: data/raw/gdp_worldbank_clean.csv
#
# All datasets downloaded and saved successfully!
# /tmp/ipykernel_7607/327312463.py:34: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   cons = cons.asfreq("A")
# /tmp/ipykernel_7607/327312463.py:52: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   gdp = gdp.asfreq("A")
